# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_14_Nov_2019_10Days.csv')
df.head()
# Out:
#               user                                     fullname  \
# 0   usLibertyWatch                              LibertyWatch.us
# 1  Remi_Vladuceanu                                 Remi Vee  🛡️
# 2      _jam_is_on_                                    jam is on
# 3    BitcoinStrats                            BitcoinStrategist
# 4      Justin_Dart  Justin Dart | My 2 Cents | Single | Bitcoin
#
#               tweet-id            timestamp  \
# 0  1051623685612802050  2018-10-14 23:59:59
# 1  1051623682802667521  2018-10-14 23:59:58
# 2  1051623659335376896  2018-10-14 23:59:53
# 3  1051623657129226240  2018-10-14 23:59:52
# 4  1051623603568107520  2018-10-14 23:59:39
#
#                                            url  likes  replies  retweets  \
# 0   /usLibertyWatch/status/1051623685612802050      0        0         0
# 1  /Remi_Vladuceanu/status/1051623682802667521      2        0         0
# 2      /_jam_is_on_/status/1051623659335376896      0        0         0
# ...

# %%
df.drop(columns = ['tweet-id','url','html'], inplace = True)
df.head()
# Out:
#               user                                     fullname  \
# 0   usLibertyWatch                              LibertyWatch.us
# 1  Remi_Vladuceanu                                 Remi Vee  🛡️
# 2      _jam_is_on_                                    jam is on
# 3    BitcoinStrats                            BitcoinStrategist
# 4      Justin_Dart  Justin Dart | My 2 Cents | Single | Bitcoin
#
#              timestamp  likes  replies  retweets  \
# 0  2018-10-14 23:59:59      0        0         0
# 1  2018-10-14 23:59:58      2        0         0
# 2  2018-10-14 23:59:53      0        0         0
# 3  2018-10-14 23:59:52      3        0         1
# 4  2018-10-14 23:59:39      1        0         0
#
#                                                 text
# 0  Join http://FreeTravelPro.com  and get PAID in...
# 1  Chinese and US Investors Team Up to Create a G...
# 2                     Tyler the Creator is a bitcoin
# 3  Week on week #btc performance • #bitcoin price...
# ...

# %%
df = df[df.likes > 0]
df = df[df.replies > 0]
df = df[df.retweets > 0]
df.head()
df.reset_index(inplace = True, drop = True)

# %%
df.head()
# Out:
#            user                             fullname            timestamp  \
# 0  CryptoSlimer  CryptoSlimer [I AM giving away ETH]  2018-10-14 23:58:32
# 1    TraderStef                           TraderStef  2018-10-14 23:58:07
# 2     carl_dong                            Carl Dong  2018-10-14 23:58:01
# 3      JoelKatz                       David Schwartz  2018-10-14 23:57:42
# 4    NiggahNews                           NiggahNews  2018-10-14 23:57:36
#
#    likes  replies  retweets                                               text
# 0      2       15         1  I like what I'm seeing from the $METM team rig...
# 1      2        1         1  #cryptocoaster #Bitcoin #crypto #cryptocurrenc...
# 2      9        1         1  It is much easier to deploy new consensus-leve...
# 3     93        3        18  But that entity would in no way, shape or form...
# 4      5        1         1  #Weekend #SoundCloud #itunes #indiemusic #appl...

# %%
df.tail()
# Out:
#                   user                     fullname            timestamp  \
# 10444       AreaCripto                  Área Cripto  2018-10-11 00:06:12
# 10445   cryptomassacre               Cryptomassacre  2018-10-11 00:05:44
# 10446  Coinboyspodcast              Coin Boys 🎙 🎤 🎧  2018-10-11 00:05:39
# 10447      CryptoBabel                    BoldBabel  2018-10-11 00:03:35
# 10448       CryptoChoe  Eric Choe [Mr. Swing Trade]  2018-10-11 00:01:23
#
#        likes  replies  retweets  \
# 10444      1        1         1
# 10445     21        7         6
# 10446     28        2         9
# 10447      2        1         1
# 10448     67        7         9
#
#                                                     text
# 10444  Não se ganha todo dia\r\n\r\nhttps://www.faceb...
# 10445  If #Tether ever collapses, it wouldn't be a cr...
# 10446  Thanks @BlakeRizzo24from @TourDeCrypto for the...
# 10447                                        #Bitcoin is
# ...

# %%
df.to_csv('Preprocessed.csv',sep=',', encoding='utf-8')
